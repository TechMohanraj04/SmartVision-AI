# %%
import tensorflow as tf

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(

    "G:/Mohanraj D_OFFICIAL/GUVI (Data Analyst)/Mini-Projects/SmartVision-AI/smartvision_dataset/classification/train",

    image_size=(224,224),

    batch_size=32
)
# Out:
# Found 1820 files belonging to 26 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(

    "G:/Mohanraj D_OFFICIAL/GUVI (Data Analyst)/Mini-Projects/SmartVision-AI/smartvision_dataset/classification/val",

    image_size=(224,224),

    batch_size=32
)
# Out:
# Found 390 files belonging to 26 classes.

# %%
# Augmentation

data_augmentation = tf.keras.Sequential([

    tf.keras.layers.RandomFlip(),

    tf.keras.layers.RandomRotation(0.1),

    tf.keras.layers.RandomZoom(0.1),

    tf.keras.layers.RandomContrast(0.1)

])
